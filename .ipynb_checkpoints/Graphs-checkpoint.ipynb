# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_1 = pd.read_csv('./cache_miss_rate.csv')

# %%
df_1.head()
# Out:
#                                         type  miss_rate
# 0   1024-n-regs_16-rob-entries_16-iq-entries   0.411625
# 1  1024-n-regs_16-rob-entries_256-iq-entries   0.411625
# 2    1024-n-regs_16-rob-entries_4-iq-entries   0.411598
# 3   1024-n-regs_16-rob-entries_64-iq-entries   0.411625
# 4  1024-n-regs_256-rob-entries_16-iq-entries   0.411721

# %%
df_2 = pd.read_csv('./sim_second.csv')

# %%
df_2.head()
# Out:
#                                         type   sim_sec
# 0   1024-n-regs_16-rob-entries_16-iq-entries  0.006321
# 1  1024-n-regs_16-rob-entries_256-iq-entries  0.006321
# 2    1024-n-regs_16-rob-entries_4-iq-entries  0.010484
# 3   1024-n-regs_16-rob-entries_64-iq-entries  0.006321
# 4  1024-n-regs_256-rob-entries_16-iq-entries  0.004909

# %%
n_regs = [64, 64, 64, 64 ,64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024]
rob_entries  = [4 , 4, 4, 4, 16, 16, 16, 16, 64, 64, 64, 64, 256, 256, 256, 256, 4 , 4, 4, 4, 16, 16, 16, 16, 64, 64, 64, 64, 256, 256, 256, 256, 4 , 4, 4, 4, 16, 16, 16, 16, 64, 64, 64, 64, 256, 256, 256, 256]
iq_entries = [4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64 ,256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64 ,256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64 ,256]

# %%
log_n_regs = list(np.log2(n_regs))
log_rob_entries = list(np.log2(rob_entries))
log_iq_entries = list(np.log2(iq_entries))

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3,2)
ax1.scatter(log_n_regs, log_rob_entries)
ax2.scatter(log_n_regs, log_iq_entries)
ax3.scatter(log_n_regs, df_1['miss_rate'])
ax4.scatter(log_n_regs, log_n_regs)
ax5.scatter(log_rob_entries, df_1['miss_rate'])
ax6.scatter(log_rob_entries, df_1['miss_rate'])

# %%
plt.rcParams["figure.figsize"] = [10.00, 7.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
img = ax.scatter(rob_entries, iq_entries, n_regs, c=df_1['miss_rate'], cmap='PuBuGn', alpha=1)
plt.colorbar(img)#, cax=cax)
ax.set_xlabel('rob_entries')
ax.set_ylabel('iq_entries')
ax.set_zlabel('n_regs')
ax.set_title("Number of Seconds Simulated")#l2 cache overall miss rate variation")#Number of Seconds Simulated")
plt.savefig("miss_rate.jpg", dpi=300)
#plt.close()

# %%
plt.rcParams["figure.figsize"] = [10.00, 7.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
img = ax.scatter(rob_entries, iq_entries, n_regs, c=df_2['sim_sec'], cmap='GnBu', alpha=1)
plt.colorbar(img)#, cax=cax)
ax.set_xlabel('rob_entries')
ax.set_ylabel('iq_entries')
ax.set_zlabel('n_regs')
ax.set_title("Number of Seconds Simulated")#l2 cache overall miss rate variation")#Number of Seconds Simulated")
plt.savefig("sim_sec.jpg", dpi=300)
#plt.close()

# %%
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
import os
# assign directory
directory = '/content/sample_data/data/'
## what parameters we want to plot
iq_rate = list()
n_regs = [64, 256, 1024]
rob_entries = [4, 16, 64, 256]
iq_entries = [4, 16, 64, 256]

# iterate over files in
# that directory
#for filename in os.listdir(directory):
#for index, f_name in enumerate(directory):
for index in range(48):
    f= "/Users/saugatpandey/Desktop/HW5/sim1/stats"+str(index+1)+".txt" 
    #f = os.path.join(directory, filename)
    #print (f)
    file = open(f, 'rb')
    lines = file.readlines()
    for index, line in enumerate(lines):
        if ("system.l2.overall_mshr_hits::total" in str(line)): #sim_seconds system.l2.overall_miss_rate::totalsim_seconds
            val = str(line).split(" ")
            #print (val[18])#sim_seconds system.l2.overall_miss_rate::total
            iq_rate.append(int(val[18]))
            
            
    
    #file.close()
#print (len(iq_rate))

#get 3 different plots for diffrent n_regs

# %%
n_regs = np.log2([64, 64, 64, 64 ,64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024, 1024])
rob_entries  = np.log2([4 , 4, 4, 4, 16, 16, 16, 16, 64, 64, 64, 64, 256, 256, 256, 256, 4 , 4, 4, 4, 16, 16, 16, 16, 64, 64, 64, 64, 256, 256, 256, 256, 4 , 4, 4, 4, 16, 16, 16, 16, 64, 64, 64, 64, 256, 256, 256, 256])
iq_entries = np.log2([4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64 ,256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64 ,256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64, 256, 4, 16, 64 ,256])

Z = iq_rate


plt.rcParams["figure.figsize"] = [10.00, 7.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
img = ax.scatter(rob_entries, iq_entries, n_regs, c=Z, cmap='winter', alpha=1)
#cax = plt.axes([0.85, 0.1, 0.075, 0.8])
plt.colorbar(img)#, cax=cax)
ax.set_xlabel('rob_entries')
ax.set_ylabel('iq_entries')
ax.set_zlabel('n_regs')
ax.set_title("L2 Cache Miss Rate")#l2 cache overall miss rate variation")#Number of Seconds Simulated")
plt.savefig("miss_rate_1.jpg", dpi=300)
#plt.close()
